# %% [markdown]
# # Control Flow

# %% [markdown]
# ## If Statement
#
# "if" statement is the most simple decision-making statement.
# It is used to decide whether a certain statement or block of statements will be executed or not i.e if a certain condition is true then a block of statement is executed otherwise not.
#
# Here, the condition after evaluation will be either true or false.
# "if" statement accepts boolean values – if the value is true then it will execute the block of statements below it
# otherwise not. We can use condition with bracket ‘(‘ ‘)’ also.
#
# ![Python_if_statement.jpg](attachment:Python_if_statement.jpg)
#
#
#
#
#
#
#
# As we know, python uses indentation to identify a block. So the block under an if statement will be identified as
# shown in the below example:

# %% [markdown]
# ## Syntax for if statement
# if condition:
#    statement1
# statement2
#
# #Here if the condition is true, if block will consider only statement1 to be inside its block.

# %%
# Example of if statement

# python program to illustrate If statement
i = 10
 
if (i > 15):
    print("10 is less than 15")
print("I am Not in if")

## As the condition present in the if statement is false. So, the block below the if statement is not executed.
# Out:
# I am Not in if

# %% [markdown]
# # if-else
#
# The if statement alone tells us that if a condition is true it will execute a block of statements and if the condition is false it won’t. But what if we want to do something else if the condition is false. Here comes the else statement. We can use the "else statement" with "if statement" to execute a block of code when the condition is "false".
#
# ![image.png](attachment:image.png)
#
# - The if-else condition is used to execute both the true and false parts of a condition.
#
# - The if block code is run if the condition is true, and the else block code is executed if the condition is false.

# %% [markdown]
# ## Syntax for if-else statement
#
# if (condition):
#     # Executes this block if
#     # condition is true
# else:
#     # Executes this block if
#     # condition is false

# %%
# Example of if-else staement

# python program to illustrate If else statement
i = 20
if (i < 15):
    print("i is smaller than 15")
    print("i'm in if Block")
else:
    print("i is greater than 15")
    print("i'm in else Block")
print("i'm not in if and not in else Block")

## The block of code following the else statement is executed as the condition present in the if statement is false.
# Out:
# i is greater than 15
# i'm in else Block
# i'm not in if and not in else Block

# %% [markdown]
# # nested - if
#
# A nested if is an "if statement" that is the target of another "if statement". Nested if statements mean an "if statement" inside another "if statement".
#
# Python allows us to nest "if statements" within "if statements". i.e, we can place an if statement inside another if statement.
#
#
# ![image.png](attachment:image.png)
#
#
# The term "nested if statement" in Python refers to the placement of one if statement inside another.
#
# - The If Else statement in Python allows us to print alternative messages based on the result of an expression (TRUE, FALSE).
#
# Even when the condition is TRUE, we sometimes need to double-check.

# %% [markdown]
# # syntax for nested-if statements
#
# if (condition1):
#    ### Executes when condition1 is true
#    if (condition2):
#       # Executes when condition2 is true
#    #### if Block is end here
# ### if Block is end here

# %%
## Example of nested-if statements

# python program to illustrate nested If statement
i = 10
if (i == 10):
   
    #  First if statement
    if (i < 15):
        print("i is smaller than 15")
         
    # Nested - if statement
    # Will only be executed if statement above is true
    if (i < 12):
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")

# %% [markdown]
# # if-elif-else ladder
#
# Here, a user can decide among multiple options. The if statements are executed from the top down.
#
# As soon as one of the conditions controlling the if is true, the statement associated with that if is executed, and the rest of the ladder is bypassed. If none of the conditions is true, then the final else statement will be executed.
#
#
# ![image.png](attachment:image.png)
#
# Elif stands for "else if." It enables us to check for several expressions at the same time.
# - If the if condition is False, the next elif block's condition is checked, and so on.
#
# - The body of else is executed if all of the conditions are False.

# %% [markdown]
# ## Syntax for if-elif-else ladder
#
# if (condition):
#     statement
# elif (condition):
#     statement
# .
# .
# else:
#     statement

# %%
## Example of if-elif-else ladder

# Python program to illustrate if-elif-else ladder
i = 20
if (i == 10):
    print("i is 10")
elif (i == 15):
    print("i is 15")
elif (i == 20):
    print("i is 20")
else:
    print("i is not present")
# Out:
# i is 20

# %% [markdown]
# # Short-Hand if statements
#
# Whenever there is only a single statement to be executed inside the if block then shorthand if can be used. The statement can be put on the same line as the if statement.
#
# ![image.png](attachment:image.png)
#
# When we just have one statement to execute in the if block and the else block
# - Shorthand if and if else is nothing more than a technique to write the if statements in one line.

# %% [markdown]
# ## Syntax of short-hand if statements
#
# if condition: statement

# %%
## Example of short-hand if statements

# Python program to illustrate short hand if
i = 10
if i < 15: print("i is less than 15")
# Out:
# i is less than 15

# %% [markdown]
# # Short-Hand if-else statement
#
# This can be used to write the if-else statements in a single line where there is only one statement to be executed in both if and else block.

# %% [markdown]
# ## Syntax of short-hand if-else statement
#
# statement_when_True if condition else statement_when_False

# %%
## Example of short hand if-else statement

# Python program to illustrate short hand if-else
i = 20
print(True) if i < 15 else print(False)
# Out:
# False

# %% [markdown]
# # Python For Loop
#
# Python For loop is used for sequential traversal i.e. it is used for iterating over an iterable like string, tuple, list, etc.
#
# It falls under the category of definite iteration. Definite iterations mean the number of repetitions is specified explicitly in advance.
#
# ![image.png](attachment:image.png)
#
# In Python, a for loop is a control flow statement that is used to execute a set of statements repeatedly as long as the condition is met.
#
# An iterative statement is another name for this type of statement.

# %% [markdown]
# ## Syntax of for loop
#
# for var in iterable:
#     # statements

# %% [markdown]
# - Here the iterable is a collection of objects like "lists, tuples".
# - The indented statements inside the for loops are executed once for each item in an iterable.
# - The variable "var" takes the value of the next item of the iterable each time through the loop.

# %%
## Example of for loop

# Python program to illustrate Iterating over a list
print("List Iteration")
l = ["welcome", "to", "RBG"]
for i in l:
    print(i)
 
# Iterating over a tuple (immutable)
print("\nTuple Iteration")
t = ("welcome", "to", "RBG.AI")
for i in t:
    print(i)
 
# Iterating over a String
print("\nString Iteration")
s = "RBG"
for i in s:
    print(i)
 
# Iterating over dictionary
print("\nDictionary Iteration")
d = dict()
d['xyz'] = 123
d['abc'] = 345
for i in d:
    print("% s % d" % (i, d[i]))

# %% [markdown]
# # Loop Control Statement
#
#
# Loop control statements are used to change the flow of execution. These can be used if you wish to skip an iteration or stop the execution. The three types of loop control statements are: break statement.
#
# Loop control statements change execution from its normal sequence. When execution leaves a scope, all automatic objects that were created in that scope are destroyed.
#
# # Continue statement
#
# Python continue Statement returns the control to the beginning of the loop.
